# %% [markdown]
# # Visualizations

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
np.random.seed(1234)

import sys
sys.path.append("../src")
from utils import data as udata
from utils import dists as udists
from utils import misc as u
from tqdm import tqdm, trange
import os.path as path
import json
import stringcase
import models
import inspect
import viz
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
EXP_DIR = "../data/processed/cdc-flusight-ensemble-live/"
INPUT_DIR = "../models/cdc-flusight-ensemble/"
TARGET = "1-ahead"
# We use all the regions as of now
REGION = None

# %%
components = [udata.Component(EXP_DIR, m) for m in udata.available_models(EXP_DIR)]
ad = udata.ActualData(EXP_DIR)

# %% [markdown]
# # Plot check

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(12, 12))

for i, ax in enumerate([ax1, ax2, ax3, ax4]):
    m = 1 - np.random.rand(100) * np.random.rand()
    m_hat = 1 - np.random.rand(100) * np.random.rand()
    color = mpl.cm.viridis(0.2 * i)

    viz.plot_mm(ax, m, m_hat, color)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
weights = np.random.rand(22, 52)
xticklabels = [f"{2000 + i}" for i in range(weights.shape[1])]
yticklabels = [chr(i + 65) for i in range(weights.shape[0])]
viz.gh_heatmap(ax, weights, xticklabels, yticklabels)
